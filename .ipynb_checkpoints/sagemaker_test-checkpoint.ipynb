# %%
# Add the conda R library path
.libPaths(c("/home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/R/library", .libPaths()))

# load the libraries
library(reticulate)
library(DBI)
library(RAthena)

# %%
# Set the correct Python path 

use_python("/home/ec2-user/anaconda3/envs/JupyterSystemEnv/bin/python", required = TRUE) 

  

# Connect to Athena 

con <- dbConnect( 

  RAthena::athena(), 

  s3_staging_dir = "s3://usgovw1-fg3-enterprise-pa3020-oepa-external-data-queryresults/", 

  region_name = "us-gov-west-1",   

  profile_name = NULL,         # use NULL if running inside SageMaker 

  work_group = "oepa-external-data" 

) 

  

# Write SQL query 

query <- 'SELECT * FROM "oepa-external-data"."census_income_dataset" LIMIT 10' 

df <- dbGetQuery(con, query)
# Out:
# INFO: (Data scanned: 64.11 KB)

# %%
df
# Out:
#    age workclass education-num marital status occupation relationship race sex
# 1  50  6         13            2              4          4            4    1
# 2  50  1         13            0              4          0            4    1
# 3  50  4         12            0              12         0            4    0
# 4  50  6         14            2              5          4            4    1
# 5  50  7         13            2              11         4            4    1
# 6  50  5         16            5              10         0            4    1
# 7  50  0         14            3              0          2            4    1
# 8  50  4         16            2              10         4            4    1
# 9  50  4         13            2              10         5            4    0
# 10 50  4         11            2              14         4            4    1
#    capital gain capital loss hours per week country y_label
# 1  0            0            13             39      false
# ...

# %%
# Getting the dimensions of the dataset
dim(df)
# Out:
# [1] 10 13
